# %% [markdown]
# ### Authors
# Cathal Crowe - 21320128 \
# Robert Flanagan - 21311625 \
# Steven Lavelle - 21316945
#
# ### Execution
# The code executes to the end without an error.
#
# ### References
# https://keras.io/examples/rl/deep_q_network_breakout \
# https://ale.farama.org/environments/breakout \
# https://gymnasium.farama.org \
# https://github.com/KJ-Waller/DQN-PyTorch-Breakout/blob/master/Breakout/DQN_model.py

# %%
# !pip install gymnasium
# !pip install ale_py

# %%
# Import our dependencies
import os
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import gymnasium as gym
from gymnasium.wrappers import (
    AtariPreprocessing,
    FrameStackObservation,
    RecordVideo,
)
import ale_py
import matplotlib.pyplot as plt

# %%
# Configure our parameters
seed = 42
gamma = 0.99
learning_rate = 0.0004
epsilon_start = 1
epsilon_end = 0.01
epsilon_decay = 0.000018
min_epsilon = 0.05
batch_size = 64
max_steps_per_episode = 1000
max_episodes = 500
replay_buffer_size = 1000000
target_update_frequency = 500
start_training_after = 10000
update_after_actions = 4
video_folder = "recorded_episodes"
epsilon = epsilon_start

# %%
# Environment setup
os.makedirs(video_folder, exist_ok=True)

gym.register_envs(ale_py)
env = gym.make("ALE/Breakout-v5", render_mode="rgb_array")
env = RecordVideo(
    env,
    video_folder=video_folder,
    episode_trigger=lambda x: x % 100 == 0,
)
env = AtariPreprocessing(env, frame_skip=1)
env = FrameStackObservation(env, 4)

env.reset(seed=seed)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# Define our model
num_actions = 4
input_dim = (4, 84, 84)
output_dim = num_actions
class DQN(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(DQN, self).__init__()
        self.input_dim = input_dim
        channels, _, _ = input_dim

        # Three convolutional layers
        self.l1 = nn.Sequential(
            nn.Conv2d(channels, 32, kernel_size=8, stride=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2, padding=1),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
        )

        # Fully connected layers
        conv_output_size = self.conv_output_dim()
        lin1_output_size = 512

        # Two linear layers
        self.l2 = nn.Sequential(
            nn.Linear(conv_output_size, lin1_output_size),
            nn.ReLU(),
            nn.Linear(lin1_output_size, output_dim),
        )

    # Returns the output dimension of the convolutional layers
    def conv_output_dim(self):
        x = torch.zeros(1, *self.input_dim)
        x = self.l1(x)
        return int(np.prod(x.shape))

    # Forward pass
    def forward(self, x):
        x = self.l1(x)
        x = x.view(x.shape[0], -1)
        actions = self.l2(x)

        return actions

model = DQN(input_dim, output_dim).to(device)
model_target = DQN(input_dim, output_dim).to(device)
model_target.load_state_dict(model.state_dict())

optimizer = optim.Adam(model.parameters(), learning_rate)

# %%
# Experience replay buffers
action_history, state_history, state_next_history = [], [], []
rewards_history, done_history = [], []
episode_reward_history = []
running_reward = 0
episode_count = 0
frame_count = 0

# %%
# Plot training performance
def plot_training_performance(episode_rewards, running_rewards):
    plt.figure(figsize=(12, 6))
    plt.plot(episode_rewards, label='Episode Reward')
    plt.plot(running_rewards, label='Running Reward')
    plt.xlabel('Episode')
    plt.ylabel('Reward')
    plt.title('Training Performance')
    plt.legend()
    plt.show()

# Collect episode rewards and running rewards
episode_rewards = []
running_rewards = []

# Train the model
try:
    while True:
        observation, _ = env.reset()
        state = np.array(observation)
        episode_reward = 0

        for timestep in range(1, max_steps_per_episode):
            frame_count += 1

            # Epsilon-greedy exploration
            if frame_count < start_training_after or epsilon > np.random.rand(1)[0]:
                action = np.random.choice(num_actions)
            else:
                with torch.no_grad():
                    state_tensor = (
                        torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(device)
                    )
                    action_probs = model(state_tensor)
                    action = action_probs.argmax().cpu().item()

            # Decay exploration
            # epsilon = max(epsilon_end, epsilon - epsilon_decay)
            epsilon = max(min_epsilon, epsilon - epsilon_decay)
            # epsilon = max(min_epsilon, epsilon_end + (epsilon_start - epsilon_end) * np.exp(-epsilon_decay * frame_count))


            # Environment step
            state_next, reward, done, _, _ = env.step(action)
            state_next = np.array(state_next)

            reward = max(min(reward, 1), -1)

            episode_reward += reward

            # Save experiences
            action_history.append(action)
            state_history.append(state)
            state_next_history.append(state_next)
            done_history.append(done)
            rewards_history.append(reward)
            state = state_next

            # Update network
            if frame_count % update_after_actions == 0 and len(done_history) > batch_size:
                # Sample batch
                indices = np.random.choice(range(len(done_history)), size=batch_size)

                # Prepare batch tensors
                state_sample = torch.tensor(
                    np.array([state_history[i] for i in indices]), dtype=torch.float32
                ).to(device)
                state_next_sample = torch.tensor(
                    np.array([state_next_history[i] for i in indices]), dtype=torch.float32
                ).to(device)
                rewards_sample = torch.tensor(
                    [rewards_history[i] for i in indices], dtype=torch.float32
                ).to(device)
                action_sample = torch.tensor(
                    [action_history[i] for i in indices], dtype=torch.long
                ).to(device)
                done_sample = torch.tensor(
                    [float(done_history[i]) for i in indices], dtype=torch.float32
                ).to(device)

                # Predict future rewards
                with torch.no_grad():
                    future_rewards = model_target(state_next_sample)
                    updated_q_values = rewards_sample + gamma * future_rewards.max(1)[0] * (
                        1 - done_sample
                    )

                # Compute Q-values
                q_values = model(state_sample)
                q_action = q_values.gather(1, action_sample.unsqueeze(1)).squeeze(1)

                # Compute loss
                loss = F.smooth_l1_loss(q_action, updated_q_values)

                # Optimize
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

            # Update target network
            if frame_count % target_update_frequency == 0:
                model_target.load_state_dict(model.state_dict())
                print(
                    f"running reward: {running_reward:.2f} at episode {episode_count}, frame count {frame_count}"
                )

            # Trim memory
            if len(rewards_history) > replay_buffer_size:
                for history in [
                    rewards_history,
                    state_history,
                    state_next_history,
                    action_history,
                    done_history,
                ]:
                    del history[:1]

            if done:
                break

        # Update running reward
        episode_reward_history.append(episode_reward)
        if len(episode_reward_history) > 100:
            del episode_reward_history[:1]
        running_reward = np.mean(episode_reward_history)

        episode_count += 1

        if episode_count > 150:
            target_update_frequency = 1500
            min_epsilon = 0.1
            epsilon_decay = 0.000002
            learning_rate = 0.0003

        if episode_count > 310:
            # learning_rate = 0.0002
            min_epsilon = 0.05
            # target_update_frequency = 1000
            epsilon_decay = 0.0000018

        # if episode_count > 400:
        #     learning_rate = 0.00015
        #     # min_epsilon = 0.01

        # comment this out if running more episodes
        #THIS PART
        #RIGHT HERE
        #  |
        #  |
        # \  /
        #  \/
        if episode_count > 498:
            learning_rate = 0.0001
            epsilon_decay = 1



        print(f"Episode {episode_count} finished with reward {episode_reward} and {epsilon}")

        # Collect rewards for plotting
        episode_rewards.append(episode_reward)
        running_rewards.append(running_reward)

        # Termination conditions
        if running_reward > 40:
            print(f"Solved at episode {episode_count}!")
            break

        if max_episodes > 0 and episode_count >= max_episodes:
            print(f"Stopped at episode {episode_count}!")
            break
finally:
    env.close()

# Plot the training performance
plot_training_performance(episode_rewards, running_rewards)
# Out:
# Episode 1 finished with reward 0.0 and 0.997588000000005
# Episode 2 finished with reward 2.0 and 0.9938080000000129
# Episode 3 finished with reward 0.0 and 0.9914140000000179
# running reward: 0.67 at episode 3, frame count 500
# Episode 4 finished with reward 1.0 and 0.9883360000000243
# Episode 5 finished with reward 3.0 and 0.9837460000000339
# running reward: 1.20 at episode 5, frame count 1000
# Episode 6 finished with reward 1.0 and 0.9807400000000401
# Episode 7 finished with reward 1.0 and 0.9775000000000469
# Episode 8 finished with reward 2.0 and 0.9733060000000556
# running reward: 1.25 at episode 8, frame count 1500
# Episode 9 finished with reward 0.0 and 0.9709660000000605
# Episode 10 finished with reward 1.0 and 0.9681220000000664
# running reward: 1.10 at episode 10, frame count 2000
# Episode 11 finished with reward 3.0 and 0.963532000000076
# Episode 12 finished with reward 1.0 and 0.9600220000000833
# Episode 13 finished with reward 1.0 and 0.9569440000000897
# running reward: 1.23 at episode 13, frame count 2500
# Episode 14 finished with reward 2.0 and 0.9533260000000973
# Episode 15 finished with reward 1.0 and 0.9499420000001043
# running reward: 1.27 at episode 15, frame count 3000
# Episode 16 finished with reward 2.0 and 0.9460000000001125
# Episode 17 finished with reward 2.0 and 0.9419860000001209
# Episode 18 finished with reward 0.0 and 0.9396460000001258
# running reward: 1.28 at episode 18, frame count 3500
# Episode 19 finished with reward 1.0 and 0.9362440000001329
# Episode 20 finished with reward 0.0 and 0.9338860000001378
# Episode 21 finished with reward 0.0 and 0.9315280000001427
# Episode 22 finished with reward 1.0 and 0.928504000000149
# running reward: 1.14 at episode 22, frame count 4000
# Episode 23 finished with reward 1.0 and 0.925156000000156
# Episode 24 finished with reward 0.0 and 0.922762000000161
# running reward: 1.08 at episode 24, frame count 4500
# Episode 25 finished with reward 3.0 and 0.9181360000001706
# Episode 26 finished with reward 3.0 and 0.9142120000001788
# Episode 27 finished with reward 0.0 and 0.9115120000001844
# running reward: 1.19 at episode 27, frame count 5000
# Episode 28 finished with reward 1.0 and 0.9084700000001907
# Episode 29 finished with reward 0.0 and 0.9060220000001958
# Episode 30 finished with reward 1.0 and 0.9031420000002018
# running reward: 1.13 at episode 30, frame count 5500
# Episode 31 finished with reward 0.0 and 0.9007480000002068
# Episode 32 finished with reward 1.0 and 0.8979040000002128
# Episode 33 finished with reward 0.0 and 0.8952940000002182
# Episode 34 finished with reward 0.0 and 0.8925400000002239
# running reward: 1.03 at episode 34, frame count 6000
# Episode 35 finished with reward 2.0 and 0.8887420000002318
# Episode 36 finished with reward 1.0 and 0.8859700000002376
# running reward: 1.06 at episode 36, frame count 6500
# Episode 37 finished with reward 4.0 and 0.8804620000002491
# Episode 38 finished with reward 2.0 and 0.8767540000002568
# Episode 39 finished with reward 0.0 and 0.8745220000002615
# running reward: 1.13 at episode 39, frame count 7000
# Episode 40 finished with reward 0.0 and 0.8717500000002673
# Episode 41 finished with reward 2.0 and 0.868042000000275
# running reward: 1.12 at episode 41, frame count 7500
# Episode 42 finished with reward 1.0 and 0.8645140000002823
# Episode 43 finished with reward 0.0 and 0.8621920000002872
# Episode 44 finished with reward 3.0 and 0.856990000000298
# running reward: 1.14 at episode 44, frame count 8000
# Episode 45 finished with reward 3.0 and 0.8516080000003092
# Episode 46 finished with reward 0.0 and 0.8490700000003145
# running reward: 1.15 at episode 46, frame count 8500
# Episode 47 finished with reward 1.0 and 0.8461180000003207
# Episode 48 finished with reward 2.0 and 0.8420140000003292
# Episode 49 finished with reward 1.0 and 0.8391520000003352
# running reward: 1.16 at episode 49, frame count 9000
# Episode 50 finished with reward 2.0 and 0.8353360000003431
# Episode 51 finished with reward 1.0 and 0.8320780000003499
# running reward: 1.18 at episode 51, frame count 9500
# Episode 52 finished with reward 1.0 and 0.828658000000357
# Episode 53 finished with reward 1.0 and 0.8256700000003633
# Episode 54 finished with reward 1.0 and 0.8224120000003701
# running reward: 1.17 at episode 54, frame count 10000
# Episode 55 finished with reward 1.0 and 0.8192440000003767
# Episode 56 finished with reward 1.0 and 0.8159320000003836
# Episode 57 finished with reward 1.0 and 0.8122780000003912
# running reward: 1.16 at episode 57, frame count 10500
# Episode 58 finished with reward 0.0 and 0.8099020000003961
# Episode 59 finished with reward 2.0 and 0.8057440000004048
# running reward: 1.15 at episode 59, frame count 11000
# Episode 60 finished with reward 4.0 and 0.8001280000004165
# Episode 61 finished with reward 2.0 and 0.7964020000004243
# Episode 62 finished with reward 0.0 and 0.7939360000004294
# running reward: 1.19 at episode 62, frame count 11500
# Episode 63 finished with reward 0.0 and 0.7914520000004346
# Episode 64 finished with reward 1.0 and 0.7883020000004411
# Episode 65 finished with reward 3.0 and 0.7841260000004499
# running reward: 1.20 at episode 65, frame count 12000
# Episode 66 finished with reward 1.0 and 0.781156000000456
# Episode 67 finished with reward 0.0 and 0.778780000000461
# running reward: 1.18 at episode 67, frame count 12500
# Episode 68 finished with reward 3.0 and 0.773992000000471
# Episode 69 finished with reward 0.0 and 0.7717420000004757
# Episode 70 finished with reward 2.0 and 0.7681780000004831
# running reward: 1.20 at episode 70, frame count 13000
# Episode 71 finished with reward 1.0 and 0.7650820000004895
# Episode 72 finished with reward 0.0 and 0.7626160000004947
# running reward: 1.18 at episode 72, frame count 13500
# Episode 73 finished with reward 4.0 and 0.7569640000005065
# Episode 74 finished with reward 2.0 and 0.7529320000005149
# Episode 75 finished with reward 1.0 and 0.7500700000005208
# running reward: 1.23 at episode 75, frame count 14000
# Episode 76 finished with reward 3.0 and 0.7455520000005302
# Episode 77 finished with reward 1.0 and 0.7421860000005372
# running reward: 1.25 at episode 77, frame count 14500
# Episode 78 finished with reward 1.0 and 0.7388740000005442
# Episode 79 finished with reward 0.0 and 0.7364440000005492
# Episode 80 finished with reward 1.0 and 0.733672000000555
# Episode 81 finished with reward 0.0 and 0.7311340000005603
# running reward: 1.21 at episode 81, frame count 15000
# Episode 82 finished with reward 4.0 and 0.7256620000005717
# running reward: 1.24 at episode 82, frame count 15500
# Episode 83 finished with reward 4.0 and 0.7201900000005831
# Episode 84 finished with reward 4.0 and 0.7150600000005938
# running reward: 1.31 at episode 84, frame count 16000
# Episode 85 finished with reward 1.0 and 0.7118920000006004
# Episode 86 finished with reward 4.0 and 0.706294000000612
# running reward: 1.34 at episode 86, frame count 16500
# Episode 87 finished with reward 3.0 and 0.7019200000006212
# Episode 88 finished with reward 4.0 and 0.6968800000006317
# running reward: 1.39 at episode 88, frame count 17000
# Episode 89 finished with reward 2.0 and 0.6930820000006396
# Episode 90 finished with reward 3.0 and 0.6882760000006496
# running reward: 1.41 at episode 90, frame count 17500
# Episode 91 finished with reward 4.0 and 0.6830380000006605
# Episode 92 finished with reward 1.0 and 0.6798340000006672
# Episode 93 finished with reward 2.0 and 0.6760360000006751
# running reward: 1.44 at episode 93, frame count 18000
# Episode 94 finished with reward 1.0 and 0.6729040000006816
# Episode 95 finished with reward 2.0 and 0.66890800000069
# running reward: 1.44 at episode 95, frame count 18500
# Episode 96 finished with reward 2.0 and 0.6650920000006979
# Episode 97 finished with reward 4.0 and 0.6599620000007086
# running reward: 1.47 at episode 97, frame count 19000
# Episode 98 finished with reward 1.0 and 0.6568120000007152
# Episode 99 finished with reward 0.0 and 0.6542380000007205
# Episode 100 finished with reward 2.0 and 0.6507820000007277
# running reward: 1.46 at episode 100, frame count 19500
# Episode 101 finished with reward 2.0 and 0.6470920000007354
# Episode 102 finished with reward 1.0 and 0.6443020000007412
# Episode 103 finished with reward 2.0 and 0.6403420000007495
# running reward: 1.49 at episode 103, frame count 20000
# Episode 104 finished with reward 3.0 and 0.6364000000007577
# Episode 105 finished with reward 1.0 and 0.6335920000007635
# running reward: 1.49 at episode 105, frame count 20500
# Episode 106 finished with reward 5.0 and 0.6279760000007752
# Episode 107 finished with reward 3.0 and 0.6231880000007852
# running reward: 1.55 at episode 107, frame count 21000
# Episode 108 finished with reward 3.0 and 0.6192280000007935
# Episode 109 finished with reward 0.0 and 0.6167080000007987
# running reward: 1.56 at episode 109, frame count 21500
# Episode 110 finished with reward 8.0 and 0.6089500000008149
# Episode 111 finished with reward 0.0 and 0.6067360000008195
# running reward: 1.60 at episode 111, frame count 22000
# Episode 112 finished with reward 2.0 and 0.6027400000008278
# Episode 113 finished with reward 1.0 and 0.5999860000008336
# running reward: 1.61 at episode 113, frame count 22500
# Episode 114 finished with reward 5.0 and 0.5941540000008457
# Episode 115 finished with reward 3.0 and 0.5896360000008551
# Episode 116 finished with reward 2.0 and 0.586360000000862
# running reward: 1.66 at episode 116, frame count 23000
# Episode 117 finished with reward 5.0 and 0.5809240000008733
# Episode 118 finished with reward 1.0 and 0.5778640000008797
# running reward: 1.70 at episode 118, frame count 23500
# Episode 119 finished with reward 1.0 and 0.5750740000008855
# Episode 120 finished with reward 6.0 and 0.5694400000008972
# running reward: 1.76 at episode 120, frame count 24000
# Episode 121 finished with reward 3.0 and 0.5651200000009062
# Episode 122 finished with reward 4.0 and 0.5602960000009163
# running reward: 1.82 at episode 122, frame count 24500
# Episode 123 finished with reward 3.0 and 0.5563180000009246
# Episode 124 finished with reward 2.0 and 0.5529340000009316
# running reward: 1.86 at episode 124, frame count 25000
# Episode 125 finished with reward 7.0 and 0.546508000000945
# running reward: 1.90 at episode 125, frame count 25500
