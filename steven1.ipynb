# %% [markdown]
# ### Authors
# Cathal Crowe - 21320128 \
# Robert Flanagan - 21311625 \
# Steven Lavelle - 21316945
#
# ### Execution
# The code executes to the end without an error.
#
# ### References
# https://keras.io/examples/rl/deep_q_network_breakout \
# https://ale.farama.org/environments/breakout \
# https://gymnasium.farama.org \
# https://github.com/KJ-Waller/DQN-PyTorch-Breakout/blob/master/Breakout/DQN_model.py

# %%
# !pip install gymnasium
# !pip install ale_py

# %%
# Import our dependencies
import os
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import gymnasium as gym
from gymnasium.wrappers import (
    AtariPreprocessing,
    FrameStackObservation,
    RecordVideo,
)
import ale_py
import matplotlib.pyplot as plt

# %%
# Configure our parameters
seed = 42
gamma = 0.99
learning_rate = 0.0003
epsilon_start = 1
epsilon_end = 0.1
epsilon_decay = 0.999
min_epsilon = 0.3
batch_size = 64
max_steps_per_episode = 1000
max_episodes = 200
replay_buffer_size = 100000
target_update_frequency = 500
start_training_after = 10000
update_after_actions = 4
video_folder = "recorded_episodes"
epsilon = epsilon_start

# %%
# Environment setup
os.makedirs(video_folder, exist_ok=True)

gym.register_envs(ale_py)
env = gym.make("ALE/Breakout-v5", render_mode="rgb_array")
env = RecordVideo(
    env,
    video_folder=video_folder,
    episode_trigger=lambda x: x % 100 == 0,
)
env = AtariPreprocessing(env, frame_skip=1)
env = FrameStackObservation(env, 4)

env.reset(seed=seed)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# /usr/local/lib/python3.10/dist-packages/gymnasium/wrappers/rendering.py:283: UserWarning: WARN: Overwriting existing videos at /content/recorded_episodes folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Using device: cuda

# %%
# Define our model
num_actions = 4
input_dim = (4, 84, 84)
output_dim = num_actions
class DQN(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(DQN, self).__init__()
        self.input_dim = input_dim
        channels, _, _ = input_dim

        # Three convolutional layers
        self.l1 = nn.Sequential(
            nn.Conv2d(channels, 32, kernel_size=8, stride=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2, padding=1),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
        )

        # Fully connected layers
        conv_output_size = self.conv_output_dim()
        lin1_output_size = 512

        # Two linear layers
        self.l2 = nn.Sequential(
            nn.Linear(conv_output_size, lin1_output_size),
            nn.ReLU(),
            nn.Linear(lin1_output_size, output_dim),
        )

    # Returns the output dimension of the convolutional layers
    def conv_output_dim(self):
        x = torch.zeros(1, *self.input_dim)
        x = self.l1(x)
        return int(np.prod(x.shape))

    # Forward pass
    def forward(self, x):
        x = self.l1(x)
        x = x.view(x.shape[0], -1)
        actions = self.l2(x)

        return actions

model = DQN(input_dim, output_dim).to(device)
model_target = DQN(input_dim, output_dim).to(device)
model_target.load_state_dict(model.state_dict())

optimizer = optim.Adam(model.parameters(), learning_rate)

# %%
# Experience replay buffers
action_history, state_history, state_next_history = [], [], []
rewards_history, done_history = [], []
episode_reward_history = []
running_reward = 0
episode_count = 0
frame_count = 0

# %%
# Plot training performance
def plot_training_performance(episode_rewards, running_rewards):
    plt.figure(figsize=(12, 6))
    plt.plot(episode_rewards, label='Episode Reward')
    plt.plot(running_rewards, label='Running Reward')
    plt.xlabel('Episode')
    plt.ylabel('Reward')
    plt.title('Training Performance')
    plt.legend()
    plt.show()

# Collect episode rewards and running rewards
episode_rewards = []
running_rewards = []

# Train the model
try:
    while True:
        observation, _ = env.reset()
        state = np.array(observation)
        episode_reward = 0

        for timestep in range(1, max_steps_per_episode):
            frame_count += 1

            # Epsilon-greedy exploration
            if frame_count < start_training_after or epsilon > np.random.rand(1)[0]:
                action = np.random.choice(num_actions)
            else:
                with torch.no_grad():
                    state_tensor = (
                        torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(device)
                    )
                    action_probs = model(state_tensor)
                    action = action_probs.argmax().cpu().item()

            # Decay exploration
            epsilon = max(epsilon_end, epsilon - epsilon_decay)

            # Environment step
            state_next, reward, done, _, _ = env.step(action)
            state_next = np.array(state_next)

            reward = max(min(reward, 1), -1)

            episode_reward += reward

            # Save experiences
            action_history.append(action)
            state_history.append(state)
            state_next_history.append(state_next)
            done_history.append(done)
            rewards_history.append(reward)
            state = state_next

            # Update network
            if frame_count % update_after_actions == 0 and len(done_history) > batch_size:
                # Sample batch
                indices = np.random.choice(range(len(done_history)), size=batch_size)

                # Prepare batch tensors
                state_sample = torch.tensor(
                    np.array([state_history[i] for i in indices]), dtype=torch.float32
                ).to(device)
                state_next_sample = torch.tensor(
                    np.array([state_next_history[i] for i in indices]), dtype=torch.float32
                ).to(device)
                rewards_sample = torch.tensor(
                    [rewards_history[i] for i in indices], dtype=torch.float32
                ).to(device)
                action_sample = torch.tensor(
                    [action_history[i] for i in indices], dtype=torch.long
                ).to(device)
                done_sample = torch.tensor(
                    [float(done_history[i]) for i in indices], dtype=torch.float32
                ).to(device)

                # Predict future rewards
                with torch.no_grad():
                    future_rewards = model_target(state_next_sample)
                    updated_q_values = rewards_sample + gamma * future_rewards.max(1)[0] * (
                        1 - done_sample
                    )

                # Compute Q-values
                q_values = model(state_sample)
                q_action = q_values.gather(1, action_sample.unsqueeze(1)).squeeze(1)

                # Compute loss
                loss = F.smooth_l1_loss(q_action, updated_q_values)

                # Optimize
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

            # Update target network
            if frame_count % target_update_frequency == 0:
                model_target.load_state_dict(model.state_dict())
                print(
                    f"running reward: {running_reward:.2f} at episode {episode_count}, frame count {frame_count}"
                )

            # Trim memory
            if len(rewards_history) > replay_buffer_size:
                for history in [
                    rewards_history,
                    state_history,
                    state_next_history,
                    action_history,
                    done_history,
                ]:
                    del history[:1]

            if done:
                break

        # Update running reward
        episode_reward_history.append(episode_reward)
        if len(episode_reward_history) > 100:
            del episode_reward_history[:1]
        running_reward = np.mean(episode_reward_history)

        episode_count += 1

        if episode_count > 100:
            target_update_frequency = 1000
            min_epsilon = 0.1

        print(f"Episode {episode_count} finished with reward {episode_reward}")

        # Collect rewards for plotting
        episode_rewards.append(episode_reward)
        running_rewards.append(running_reward)

        # Termination conditions
        if running_reward > 40:
            print(f"Solved at episode {episode_count}!")
            break

        if max_episodes > 0 and episode_count >= max_episodes:
            print(f"Stopped at episode {episode_count}!")
            break
finally:
    env.close()

# Plot the training performance
plot_training_performance(episode_rewards, running_rewards)
# Out:
# Episode 1 finished with reward 1.0
# Episode 2 finished with reward 1.0
# running reward: 1.00 at episode 2, frame count 500
# Episode 3 finished with reward 2.0
# Episode 4 finished with reward 1.0
# Episode 5 finished with reward 0.0
# running reward: 1.00 at episode 5, frame count 1000
# Episode 6 finished with reward 1.0
# Episode 7 finished with reward 0.0
# Episode 8 finished with reward 0.0
# running reward: 0.75 at episode 8, frame count 1500
# Episode 9 finished with reward 5.0
# Episode 10 finished with reward 0.0
# Episode 11 finished with reward 2.0
# running reward: 1.18 at episode 11, frame count 2000
# Episode 12 finished with reward 0.0
# Episode 13 finished with reward 1.0
# Episode 14 finished with reward 3.0
# running reward: 1.21 at episode 14, frame count 2500
# Episode 15 finished with reward 2.0
# Episode 16 finished with reward 2.0
# running reward: 1.31 at episode 16, frame count 3000
# Episode 17 finished with reward 2.0
# Episode 18 finished with reward 3.0
# running reward: 1.44 at episode 18, frame count 3500
# Episode 19 finished with reward 2.0
# Episode 20 finished with reward 2.0
# running reward: 1.50 at episode 20, frame count 4000
# Episode 21 finished with reward 2.0
# Episode 22 finished with reward 1.0
# Episode 23 finished with reward 0.0
# Episode 24 finished with reward 1.0
# running reward: 1.42 at episode 24, frame count 4500
# Episode 25 finished with reward 0.0
# Episode 26 finished with reward 2.0
# Episode 27 finished with reward 0.0
# running reward: 1.33 at episode 27, frame count 5000
# Episode 28 finished with reward 0.0
# Episode 29 finished with reward 3.0
# running reward: 1.34 at episode 29, frame count 5500
# Episode 30 finished with reward 5.0
# Episode 31 finished with reward 0.0
# running reward: 1.42 at episode 31, frame count 6000
# Episode 32 finished with reward 3.0
# Episode 33 finished with reward 0.0
# Episode 34 finished with reward 3.0
# running reward: 1.47 at episode 34, frame count 6500
# Episode 35 finished with reward 1.0
# Episode 36 finished with reward 0.0
# Episode 37 finished with reward 2.0
# running reward: 1.43 at episode 37, frame count 7000
# Episode 38 finished with reward 2.0
# Episode 39 finished with reward 1.0
# running reward: 1.44 at episode 39, frame count 7500
# Episode 40 finished with reward 3.0
# Episode 41 finished with reward 2.0
# Episode 42 finished with reward 1.0
# running reward: 1.48 at episode 42, frame count 8000
# Episode 43 finished with reward 2.0
# Episode 44 finished with reward 0.0
# Episode 45 finished with reward 0.0
# running reward: 1.42 at episode 45, frame count 8500
# Episode 46 finished with reward 1.0
# Episode 47 finished with reward 0.0
# running reward: 1.38 at episode 47, frame count 9000
# Episode 48 finished with reward 4.0
# Episode 49 finished with reward 0.0
# Episode 50 finished with reward 2.0
# running reward: 1.42 at episode 50, frame count 9500
# Episode 51 finished with reward 0.0
# Episode 52 finished with reward 2.0
# running reward: 1.40 at episode 52, frame count 10000
# Episode 53 finished with reward 3.0
# Episode 54 finished with reward 2.0
# running reward: 1.44 at episode 54, frame count 10500
# Episode 55 finished with reward 5.0
# Episode 56 finished with reward 4.0
# running reward: 1.55 at episode 56, frame count 11000
# Episode 57 finished with reward 4.0
# running reward: 1.60 at episode 57, frame count 11500
# Episode 58 finished with reward 3.0
# Episode 59 finished with reward 0.0
# running reward: 1.59 at episode 59, frame count 12000
# Episode 60 finished with reward 4.0
# Episode 61 finished with reward 1.0
# running reward: 1.62 at episode 61, frame count 12500
# Episode 62 finished with reward 3.0
# Episode 63 finished with reward 1.0
# running reward: 1.63 at episode 63, frame count 13000
# Episode 64 finished with reward 1.0
# running reward: 1.62 at episode 64, frame count 13500
# Episode 65 finished with reward 5.0
# Episode 66 finished with reward 4.0
# running reward: 1.71 at episode 66, frame count 14000
# Episode 67 finished with reward 2.0
# Episode 68 finished with reward 4.0
# running reward: 1.75 at episode 68, frame count 14500
# Episode 69 finished with reward 4.0
# running reward: 1.78 at episode 69, frame count 15000
# Episode 70 finished with reward 3.0
# Episode 71 finished with reward 5.0
# running reward: 1.85 at episode 71, frame count 15500
# Episode 72 finished with reward 2.0
# Episode 73 finished with reward 4.0
# running reward: 1.88 at episode 73, frame count 16000
# Episode 74 finished with reward 4.0
# Episode 75 finished with reward 5.0
# running reward: 1.95 at episode 75, frame count 16500
# Episode 76 finished with reward 4.0
# running reward: 1.97 at episode 76, frame count 17000
# Episode 77 finished with reward 6.0
# Episode 78 finished with reward 3.0
# running reward: 2.04 at episode 78, frame count 17500
# Episode 79 finished with reward 4.0
# Episode 80 finished with reward 2.0
# running reward: 2.06 at episode 80, frame count 18000
# Episode 81 finished with reward 2.0
# Episode 82 finished with reward 1.0
# running reward: 2.05 at episode 82, frame count 18500
# Episode 83 finished with reward 4.0
# Episode 84 finished with reward 6.0
# running reward: 2.12 at episode 84, frame count 19000
# Episode 85 finished with reward 5.0
# Episode 86 finished with reward 6.0
# running reward: 2.20 at episode 86, frame count 19500
# Episode 87 finished with reward 7.0
# running reward: 2.25 at episode 87, frame count 20000
# Episode 88 finished with reward 3.0
# Episode 89 finished with reward 3.0
# Episode 90 finished with reward 1.0
# running reward: 2.26 at episode 90, frame count 20500
# Episode 91 finished with reward 1.0
# Episode 92 finished with reward 3.0
# Episode 93 finished with reward 2.0
# running reward: 2.25 at episode 93, frame count 21000
# Episode 94 finished with reward 1.0
# Episode 95 finished with reward 3.0
# running reward: 2.24 at episode 95, frame count 21500
# Episode 96 finished with reward 3.0
# Episode 97 finished with reward 5.0
# running reward: 2.28 at episode 97, frame count 22000
# Episode 98 finished with reward 1.0
# Episode 99 finished with reward 1.0
# Episode 100 finished with reward 4.0
# running reward: 2.27 at episode 100, frame count 22500
# Episode 101 finished with reward 4.0
# running reward: 2.30 at episode 101, frame count 23000
# Episode 102 finished with reward 5.0
# Episode 103 finished with reward 4.0
# Episode 104 finished with reward 1.0
# Episode 105 finished with reward 3.0
# Episode 106 finished with reward 5.0
# running reward: 2.43 at episode 106, frame count 24000
# Episode 107 finished with reward 3.0
# Episode 108 finished with reward 3.0
# Episode 109 finished with reward 5.0
# Episode 110 finished with reward 3.0
# running reward: 2.52 at episode 110, frame count 25000
# Episode 111 finished with reward 2.0
# Episode 112 finished with reward 3.0
# Episode 113 finished with reward 3.0
# Episode 114 finished with reward 4.0
# running reward: 2.58 at episode 114, frame count 26000
# Episode 115 finished with reward 3.0
# Episode 116 finished with reward 5.0
# Episode 117 finished with reward 3.0
# Episode 118 finished with reward 3.0
# running reward: 2.63 at episode 118, frame count 27000
# Episode 119 finished with reward 4.0
# Episode 120 finished with reward 6.0
# Episode 121 finished with reward 4.0
# running reward: 2.71 at episode 121, frame count 28000
# Episode 122 finished with reward 5.0
# Episode 123 finished with reward 5.0
# Episode 124 finished with reward 7.0
# running reward: 2.86 at episode 124, frame count 29000
# Episode 125 finished with reward 4.0
# Episode 126 finished with reward 6.0
# Episode 127 finished with reward 2.0
# running reward: 2.96 at episode 127, frame count 30000
# Episode 128 finished with reward 6.0
# Episode 129 finished with reward 6.0
# Episode 130 finished with reward 8.0
# running reward: 3.08 at episode 130, frame count 31000
# Episode 131 finished with reward 5.0
# Episode 132 finished with reward 4.0
# Episode 133 finished with reward 6.0
# running reward: 3.20 at episode 133, frame count 32000
# Episode 134 finished with reward 6.0
# Episode 135 finished with reward 6.0
# Episode 136 finished with reward 5.0
# running reward: 3.33 at episode 136, frame count 33000
# Episode 137 finished with reward 5.0
# Episode 138 finished with reward 8.0
# Episode 139 finished with reward 2.0
# running reward: 3.43 at episode 139, frame count 34000
# Episode 140 finished with reward 7.0
# Episode 141 finished with reward 3.0
# Episode 142 finished with reward 5.0
# Episode 143 finished with reward 3.0
# running reward: 3.53 at episode 143, frame count 35000
# Episode 144 finished with reward 3.0
# Episode 145 finished with reward 3.0
# Episode 146 finished with reward 5.0
# running reward: 3.63 at episode 146, frame count 36000
# Episode 147 finished with reward 5.0
# Episode 148 finished with reward 4.0
# Episode 149 finished with reward 3.0
# Episode 150 finished with reward 1.0
# Episode 151 finished with reward 4.0
# running reward: 3.74 at episode 151, frame count 37000
# Episode 152 finished with reward 3.0
# Episode 153 finished with reward 4.0
# Episode 154 finished with reward 4.0
# running reward: 3.78 at episode 154, frame count 38000
# Episode 155 finished with reward 6.0
# Episode 156 finished with reward 6.0
# Episode 157 finished with reward 4.0
# running reward: 3.81 at episode 157, frame count 39000
# Episode 158 finished with reward 4.0
# Episode 159 finished with reward 3.0
# Episode 160 finished with reward 3.0
# Episode 161 finished with reward 5.0
# running reward: 3.88 at episode 161, frame count 40000
# Episode 162 finished with reward 4.0
# Episode 163 finished with reward 5.0
# Episode 164 finished with reward 6.0
# Episode 165 finished with reward 3.0
# running reward: 3.96 at episode 165, frame count 41000
# Episode 166 finished with reward 9.0
# Episode 167 finished with reward 3.0
# running reward: 4.02 at episode 167, frame count 42000
# Episode 168 finished with reward 7.0
# Episode 169 finished with reward 2.0
# Episode 170 finished with reward 3.0
# Episode 171 finished with reward 5.0
# running reward: 4.03 at episode 171, frame count 43000
# Episode 172 finished with reward 6.0
# Episode 173 finished with reward 4.0
# Episode 174 finished with reward 4.0
# running reward: 4.07 at episode 174, frame count 44000
# Episode 175 finished with reward 6.0
# Episode 176 finished with reward 5.0
# Episode 177 finished with reward 4.0
# running reward: 4.07 at episode 177, frame count 45000
# Episode 178 finished with reward 4.0
# Episode 179 finished with reward 6.0
# Episode 180 finished with reward 6.0
# running reward: 4.14 at episode 180, frame count 46000
# Episode 181 finished with reward 4.0
# Episode 182 finished with reward 5.0
# Episode 183 finished with reward 4.0
# Episode 184 finished with reward 4.0
# running reward: 4.18 at episode 184, frame count 47000
# Episode 185 finished with reward 3.0
# Episode 186 finished with reward 7.0
# Episode 187 finished with reward 3.0
# running reward: 4.13 at episode 187, frame count 48000
# Episode 188 finished with reward 3.0
# Episode 189 finished with reward 5.0
# Episode 190 finished with reward 8.0
# running reward: 4.22 at episode 190, frame count 49000
# Episode 191 finished with reward 8.0
# Episode 192 finished with reward 4.0
# Episode 193 finished with reward 3.0
# Episode 194 finished with reward 3.0
# running reward: 4.33 at episode 194, frame count 50000
# Episode 195 finished with reward 9.0
# Episode 196 finished with reward 9.0
# running reward: 4.45 at episode 196, frame count 51000
# Episode 197 finished with reward 5.0
# Episode 198 finished with reward 5.0
# Episode 199 finished with reward 5.0
# running reward: 4.53 at episode 199, frame count 52000
# Episode 200 finished with reward 9.0
# Stopped at episode 200!
